# %%
# !pip install openai-whisper
# !pip install google-generativeai
# !pip install gtts
# !pip install soundfile
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.2/803.2 kB 45.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for openai-whisper: filename=openai_whisper-20250625-py3-none-any.whl size=803979 sha256=6f5ff15efc566d5342a6736594e566a10a526e85f3657d7f6aeacfa61703120d
#   Stored in directory: /root/.cache/pip/wheels/61/d2/20/09ec9bef734d126cba375b15898010b6cc28578d8afdde5869
# Successfully built openai-whisper
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 9.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: click
#     Found existing installation: click 8.4.2
#     Uninstalling click-8.4.2:
#       Successfully uninstalled click-8.4.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# !apt-get update -qq
# !apt-get install -y ffmpeg
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 145 not upgraded.

# %%
# !pip install -q google-genai

# %%
import whisper
from google import genai
from gtts import gTTS
from IPython.display import Audio

# %%
import torch


print(torch.cuda.is_available())
# Out:
# True

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

model = whisper.load_model("base").to(device)

print("Whisper loaded on:", device)
# Out:
# 100%|████████████████████████████████████████| 139M/139M [00:01<00:00, 139MiB/s]
# Whisper loaded on: cuda

# %%
model = whisper.load_model("base")

print("Whisper model loaded successfully!")
# Out:
# 100%|████████████████████████████████████████| 139M/139M [00:01<00:00, 116MiB/s]
# Whisper model loaded successfully!

# %%
result = model.transcribe("/content/harvard.wav")

text = result["text"]

print(text)
# Out:
#  The stale smell of old beer lingers. It takes heat to bring out the odor. A cold dip restores health and zest. A salt pickle tastes fine with ham. Tacos al pastor are my favorite. A zestful food is the hot cross bun.

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-42d5077a-ae5d-4368-b38b-6484abdd30e7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-42d5077a-ae5d-4368-b38b-6484abdd30e7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os

print(os.listdir())
# Out:
# ['.config', 'WhatsApp Ptt 2026-07-19 at 12.36.46 AM.ogg', 'harvard (1).wav', 'harvard.wav', 'sample_data']

# %%
audio_file = "WhatsApp Ptt 2026-07-19 at 12.36.46 AM.ogg"

result = model.transcribe(audio_file)

text = result["text"]

print("You said:", text)
# Out:
# You said:  Hello, my name is Prano, what is artificial intelligence?

# %%
from google import genai

client = genai.Client(
    api_key="SET GEMINI API KEY"
)

print("Gemini connected successfully!")
# Out:
# Gemini connected successfully!

# %%
for model in client.models.list():
    print(model.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-4-26b-a4b-it
# models/gemma-4-31b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3.1-flash-lite
# models/gemini-3-pro-image-preview
# models/gemini-3-pro-image
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/gemini-3.1-flash-image
# models/gemini-3.1-flash-lite-image
# models/gemini-3.5-flash
# models/gemini-omni-flash-preview
# models/lyria-3-clip-preview
# models/lyria-3-pro-preview
# ...

# %%
for m in client.models.list():
    print(m.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-4-26b-a4b-it
# models/gemma-4-31b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3.1-flash-lite
# models/gemini-3-pro-image-preview
# models/gemini-3-pro-image
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/gemini-3.1-flash-image
# models/gemini-3.1-flash-lite-image
# models/gemini-3.5-flash
# models/gemini-omni-flash-preview
# models/lyria-3-clip-preview
# models/lyria-3-pro-preview
# ...

# %%
response = client.models.generate_content(
    model="gemini-flash-latest",
    contents=text
)

answer = response.text

print(answer)
# Out:
# Hello, Prano! It is great to meet you.
#
# To put it simply, **Artificial Intelligence (AI)** is a branch of computer science that focuses on building smart machines capable of performing tasks that typically require human intelligence.
#
# Instead of just following a strict, pre-written set of instructions, AI systems can learn from data, make decisions, solve problems, and adapt to new situations.
#
# Here is a quick breakdown of how it works and how we use it every day:
#
# ### 1. How does AI work?
# Most modern AI relies on **Machine Learning**. Instead of coding a computer with every single rule, we feed it massive amounts of data (like pictures, text, or numbers). The computer analyzes this data to find patterns and learns how to make predictions or decisions on its own.
#
# ### 2. Examples of AI you probably use already:
# * **Smart Assistants:** Siri, Alexa, and Google Assistant use AI to understand your voice and answer your questions.
# ...

# %%
from gtts import gTTS
from IPython.display import Audio

tts = gTTS(
    text=answer,
    lang="en"
)

tts.save("assistant_response.mp3")

print("Voice generated successfully!")
# Out:
# Voice generated successfully!

# %%
Audio("assistant_response.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
